# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv', sep=';')

df.columns
# Out:
# Index(['Время', 'Мощность МПСИ 1', 'Мощность МПСИ 2', 'Мощность МШЦ 1',
#        'Мощность МШЦ 2', 'Ток МПСИ 1', 'Ток МПСИ 2', 'Ток МШЦ 1', 'Ток МШЦ 2',
#        'Питание МПСИ 1', 'Питание МПСИ 2', 'Возврат руды МПСИ 1',
#        'Возврат руды МПСИ 2', 'Расход воды МПСИ 1 PV', 'Расход воды МПСИ 2 PV',
#        'Расход воды МПСИ 1 SP', 'Расход воды МПСИ 2 SP',
#        'Расход воды МПСИ 1 CV', 'Расход воды МПСИ 2 CV',
#        'факт соотношение руда/вода МПСИ 1',
#        'факт соотношение руда/вода МПСИ 2',
#        'Давление на подшипник МПСИ 1 загрузка',
#        'Давление на подшипник МПСИ 2 загрузка',
#        'Давление на подшипник МПСИ 1 разгрузка',
#        'Давление на подшипник МПСИ 2 разгрузка', 'Расход оборотной воды 1',
#        'Расход оборотной воды 2', 'pH оборотной воды', 't оборотной воды',
#        'Гранулометрия 1', 'Гранулометрия 2', 'Поток 1', 'Поток 2'],
#       dtype='object')

# %%
# Участки делятся на 2 разные обсласти, поэтому делим данные на 2 разных датафрейма

# Первая область
DataFromFirstArea = df[[column for column in df.columns if '2' not in column]]
DataFromFirstArea.head(3)
# Out:
#              Время  Мощность МПСИ 1  Мощность МШЦ 1  Ток МПСИ 1   Ток МШЦ 1  \
# 0  14.10.2022 9:41      2775.416504     3362.618408  311.261475  367.854431
# 1  14.10.2022 9:42      2782.308105     3360.184326  310.980560  367.691681
# 2  14.10.2022 9:43      2790.591797     3369.075195  312.216309  368.021637
#
#    Питание МПСИ 1  Возврат руды МПСИ 1  Расход воды МПСИ 1 PV  \
# 0      419.317566            33.067596             130.680298
# 1      366.358826            31.507715             130.702927
# 2      407.251831            29.047806             131.193375
#
#    Расход воды МПСИ 1 SP  Расход воды МПСИ 1 CV  \
# 0              97.791168                   60.0
# 1             105.495728                   60.0
# 2              96.301971                   60.0
#
#    факт соотношение руда/вода МПСИ 1  Давление на подшипник МПСИ 1 загрузка  \
# 0                           0.308750                              49.830559
# ...

# %%
# Вторая область
DataFromSecondArea = df[[column for column in df.columns if '1' not in column]]
DataFromSecondArea.head(3)
# Out:
#              Время  Мощность МПСИ 2  Мощность МШЦ 2  Ток МПСИ 2   Ток МШЦ 2  \
# 0  14.10.2022 9:41      2867.076172     3211.990723  313.438446  351.281342
# 1  14.10.2022 9:42      2863.872559     3213.338867  312.871735  351.527618
# 2  14.10.2022 9:43      2853.717529     3214.086670  312.942566  351.625549
#
#    Питание МПСИ 2  Возврат руды МПСИ 2  Расход воды МПСИ 2 PV  \
# 0      564.305176           116.449532             137.490555
# 1      604.075989           121.444908             137.414474
# 2      542.401245           119.061829             137.517899
#
#    Расход воды МПСИ 2 SP  Расход воды МПСИ 2 CV  \
# 0             142.543610              99.386932
# 1             149.055023              99.634628
# 2             159.654633              99.805397
#
#    факт соотношение руда/вода МПСИ 2  Давление на подшипник МПСИ 2 загрузка  \
# 0                           0.210562                              47.143127
# ...
